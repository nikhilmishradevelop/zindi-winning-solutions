# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
import gc
from fastai.tabular import *
from sklearn.metrics import mean_squared_error as mse
from sklearn.model_selection import KFold, StratifiedKFold
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import datetime
from tqdm import tqdm_notebook

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mse(y_true, y_pred))

# %%
train = pd.read_csv('/kaggle/input/zindi-weekendz-pollution/Train.csv')
test = pd.read_csv('/kaggle/input/zindi-weekendz-pollution/Test.csv')
sample_sub = pd.read_csv('/kaggle/input/zindi-weekendz-pollution/SampleSubmission.csv')

# %%
train['Date'] = pd.to_datetime(train['Date'], format='%Y-%m-%d')
test['Date'] = pd.to_datetime(test['Date'], format='%Y-%m-%d')
ID_COL, TARGET_COL = 'Place_ID X Date', 'target'
df = pd.concat([train, test]).reset_index(drop=True)
features = [c for c in df.columns if c not in ['Date', 'target_count', 'target_min', 'Place_ID X Date', 'target_variance', 'Place_ID', 'target_max', 'target']]
simple_feats = [c for c in features if ('angle' not in c) & ('height' not in c) & ('altittude' not in c)]
len(simple_feats)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   after removing the cwd from sys.path.
# 38

# %%
df['placeID_freq'] = df['Place_ID'].map(df['Place_ID'].value_counts())
for i in range(1, 20):
    df[f'prev_target_{i}'] = df.sort_values(by='Date')[TARGET_COL].fillna(method='ffill').shift(i).sort_index()
    df[f'next_target_{i}'] = df.sort_values(by='Date')[TARGET_COL].fillna(method='bfill').shift(-i).sort_index()

for i in tqdm_notebook(range(1, 15)):
    df[f'magic_{i}'] = df.sort_values(by='Date')[TARGET_COL].shift(i).expanding().mean().fillna(method='ffill').sort_index()
    df[f'magic2_{i}'] = df.sort_values(by='Date')[TARGET_COL].shift(-i).expanding().mean().fillna(method='bfill').sort_index()
    
for i in tqdm_notebook(range(1, 45)):
    c = 'Date' + str(i+1)
    df[c] = df['Date']  + datetime.timedelta(days=i)
    _ = add_cyclic_datepart(df, c, prefix = c)
    
for i in tqdm_notebook(range(1, 11)):
    tmp = df.sort_values(by='Date').groupby('Place_ID')[simple_feats].shift(i).sort_index()
    tmp_diff_prev = df[simple_feats] - tmp
    tmp.columns = [c + f'_prev_{i}' for c in tmp.columns]
    tmp_diff_prev.columns = [c + f'_prev_diff_{i}' for c in tmp_diff_prev.columns]
    df = pd.concat([df, tmp, tmp_diff_prev], axis=1)
    
    tmp = df.sort_values(by='Date').groupby('Place_ID')[simple_feats].shift(-i).sort_index()
    tmp_diff_next = df[simple_feats] - tmp
    tmp.columns = [c + f'_next_{i}' for c in tmp.columns]
    tmp_diff_next.columns = [c + f'_next_diff_{i}' for c in tmp_diff_next.columns]
    df = pd.concat([df, tmp, tmp_diff_next], axis=1)
    
for attr in ['day', 'month', 'week', 'dayofweek', 'weekofyear', 'days_in_month', 'is_month_start', 'is_month_end', 'dayofyear']:
    df[attr] = getattr(df['Date'].dt, attr)
df['is_weekend'] = (df['dayofweek'] >= 5)*1
df['fortnight'] = df['day']%15
df['which_fortnight'] = df['day']//15
add_cyclic_datepart(df, "Date", prefix = "Current_Date_")
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:10: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   # Remove the CWD from sys.path while we load stuff.
# HBox(children=(FloatProgress(value=0.0, max=44.0), HTML(value='')))
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:15: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   from ipykernel import kernelapp as app
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
#        L3_AER_AI_absorbing_aerosol_index  L3_AER_AI_sensor_altitude  \
# 0                              -1.231330              840209.874619
# 1                              -1.082553              840772.941995
# 2                              -1.001241              841410.713456
# 3                              -0.777023              841103.242368
# 4                               0.366324              840763.055499
# ...                                  ...                        ...
# 46688                          -1.011116              833312.353691
# 46689                          -1.363941              833125.012462
# 46690                          -1.776128              832573.386814
# 46691                          -2.971064              832687.223024
# 46692                          -1.582332              832878.418266
#
#        L3_AER_AI_sensor_azimuth_angle  L3_AER_AI_sensor_zenith_angle  \
# 0                           76.537512                      38.634284
# 1                          -14.708036                      59.624912
# 2                         -105.201338                      49.839714
# 3                         -104.334056                      29.180977
# 4                           58.850179                       0.797294
# ...                               ...                            ...
# 46688                       63.241090                      51.611371
# 46689                      -17.869847                      55.065521
# 46690                      -99.647714                      27.132738
# 46691                       38.739218                       0.564620
# 46692                       69.812062                      27.292029
#
#        L3_AER_AI_solar_azimuth_angle  L3_AER_AI_solar_zenith_angle  \
# 0                         -61.736719                     22.358167
# 1                         -67.693509                     28.614804
# 2                         -78.342701                     34.296977
# 3                         -73.896572                     30.545393
# 4                         -68.612480                     26.899694
# ...                              ...                           ...
# 46688                    -176.521720                     38.857262
# 46689                      15.079379                     40.886310
# 46690                    -152.254156                     41.190326
# 46691                    -158.883352                     39.431193
# 46692                    -165.900429                     38.047473
#
#        L3_CH4_CH4_column_volume_mixing_ratio_dry_air  L3_CH4_aerosol_height  \
# 0                                        1793.793579            3227.855469
# 1                                        1789.960449            3384.226562
# 2                                                NaN                    NaN
# 3                                                NaN                    NaN
# 4                                                NaN                    NaN
# ...                                              ...                    ...
# 46688                                            NaN                    NaN
# 46689                                            NaN                    NaN
# 46690                                            NaN                    NaN
# 46691                                       0.000000               0.000000
# 46692                                            NaN                    NaN
#
#        L3_CH4_aerosol_optical_depth  L3_CH4_sensor_azimuth_angle  ...  \
# 0                          0.010579                    74.481049  ...
# 1                          0.015104                    75.630043  ...
# 2                               NaN                          NaN  ...
# 3                               NaN                          NaN  ...
# 4                               NaN                          NaN  ...
# ...                             ...                          ...  ...
# 46688                           NaN                          NaN  ...
# 46689                           NaN                          NaN  ...
# 46690                           NaN                          NaN  ...
# 46691                      0.000000                     0.000000  ...
# 46692                           NaN                          NaN  ...
#
#        fortnight  which_fortnight  Current_Date_weekday_cos  \
# 0              2                0                 -0.900969
# 1              3                0                 -0.900969
# 2              4                0                 -0.222521
# 3              5                0                  0.623490
# 4              6                0                  1.000000
# ...          ...              ...                       ...
# 46688          1                2                  0.623490
# 46689          1                0                 -0.222521
# 46690          2                0                 -0.900969
# 46691          3                0                 -0.900969
# 46692          4                0                 -0.222521
#
#        Current_Date_weekday_sin  Current_Date_day_month_cos  \
# 0                      0.433884                    0.979530
# 1                     -0.433884                    0.918958
# 2                     -0.974928                    0.820763
# 3                     -0.781831                    0.688967
# 4                      0.000000                    0.528964
# ...                         ...                         ...
# 46688                  0.781831                    0.979530
# 46689                  0.974928                    1.000000
# 46690                  0.433884                    0.978148
# 46691                 -0.433884                    0.913545
# 46692                 -0.974928                    0.809017
#
#        Current_Date_day_month_sin  Current_Date_month_year_cos  \
# 0                        0.201299                 1.000000e+00
# 1                        0.394356                 1.000000e+00
# 2                        0.571268                 1.000000e+00
# 3                        0.724793                 1.000000e+00
# 4                        0.848644                 1.000000e+00
# ...                           ...                          ...
# 46688                   -0.201299                 5.000000e-01
# 46689                    0.000000                 6.123234e-17
# 46690                    0.207912                 6.123234e-17
# 46691                    0.406737                 6.123234e-17
# 46692                    0.587785                 6.123234e-17
#
#        Current_Date_month_year_sin  Current_Date_day_year_cos  \
# 0                         0.000000                   0.999853
# 1                         0.000000                   0.999411
# 2                         0.000000                   0.998674
# 3                         0.000000                   0.997643
# 4                         0.000000                   0.996318
# ...                            ...                        ...
# 46688                     0.866025                   0.025748
# 46689                     1.000000                   0.008583
# 46690                     1.000000                  -0.008583
# 46691                     1.000000                  -0.025748
# 46692                     1.000000                  -0.042905
#
#        Current_Date_day_year_sin
# 0                       0.017166
# 1                       0.034328
# 2                       0.051479
# 3                       0.068615
# 4                       0.085731
# ...                          ...
# 46688                   0.999668
# 46689                   0.999963
# 46690                   0.999963
# 46691                   0.999668
# 46692                   0.999079
#
# [46693 rows x 2040 columns]

# %%
features = [c for c in df.columns if c not in ['Date', 'target_count', 'target_min', 'Place_ID X Date', 'target_variance', 'Place_ID',
                                               'target_max', 'target',  'month_year_cos','month_year_sin','day_year_cos','day_year_sin']]
train = df[:train.shape[0]].reset_index(drop=True)
test = df[train.shape[0]:].reset_index(drop=True)
target = train[TARGET_COL]
len(features)
# Out:
# 2033

# %%
param = {'num_leaves': 100,
         'min_data_in_leaf': 40, 
         'objective':'regression',
         'max_depth': -1,
         'learning_rate': 0.05,
         "boosting": "gbdt",
         "feature_fraction": 0.35,
         "metric": 'auc',
         "lambda_l1": 1,
         "lambda_l2": 1,
         "random_state": 6,
         "verbosity": -1,
          'metric' : 'rmse',
          'num_iterations': 2200}

# %%
target_cols = ['target']
oofs_df = pd.DataFrame()
preds_df = pd.DataFrame()
for t_col in target_cols:
    oofs_df[t_col] = np.zeros(len(train))
    preds_df[t_col] = np.zeros(len(test))

# %%
max_iter = 10
folds = StratifiedKFold(n_splits=max_iter, random_state=1901)

for fold_, (trn_idx, val_idx) in enumerate(folds.split(train.values, pd.qcut(target, 10, labels=False, duplicates='drop'))):
    print("\nfold n°{}".format(fold_))
    X_trn, X_val, X_test = train.iloc[trn_idx][features], train.iloc[val_idx][features], test[features]
    for t_col in target_cols:
        target = train[t_col]
        print(f"\n\n**** {t_col} ****\n")
        y_trn, y_val = target.iloc[trn_idx], target.iloc[val_idx]
        trn_data = lgb.Dataset(X_trn, y_trn)
        val_data = lgb.Dataset(X_val, y_val)
        
        clf = lgb.train(param, trn_data, valid_sets = [trn_data, val_data], verbose_eval=50, early_stopping_rounds = 200)

        oofs_df[t_col][val_idx] = clf.predict(X_val, num_iteration=clf.best_iteration)
        current_test_pred = clf.predict(X_test, num_iteration=clf.best_iteration)
        current_test_pred[current_test_pred < 0] = 0
        preds_df[t_col] += current_test_pred / folds.n_splits
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/model_selection/_split.py:296: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning
# fold n°0
#
#
# **** target ****
# /opt/conda/lib/python3.6/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# Training until validation scores don't improve for 200 rounds
# [50]	training's rmse: 24.0208	valid_1's rmse: 27.5112
# [100]	training's rmse: 18.4122	valid_1's rmse: 25.2746
# [150]	training's rmse: 15.1519	valid_1's rmse: 24.4215
# [200]	training's rmse: 12.8191	valid_1's rmse: 24.079
# [250]	training's rmse: 10.9921	valid_1's rmse: 23.966
# [300]	training's rmse: 9.56156	valid_1's rmse: 23.872
# [350]	training's rmse: 8.41092	valid_1's rmse: 23.809
# [400]	training's rmse: 7.44362	valid_1's rmse: 23.7812
# [450]	training's rmse: 6.62425	valid_1's rmse: 23.7123
# [500]	training's rmse: 5.92084	valid_1's rmse: 23.6805
# [550]	training's rmse: 5.31286	valid_1's rmse: 23.661
# [600]	training's rmse: 4.7736	valid_1's rmse: 23.6362
# [650]	training's rmse: 4.30161	valid_1's rmse: 23.5994
# [700]	training's rmse: 3.8821	valid_1's rmse: 23.5872
# [750]	training's rmse: 3.51717	valid_1's rmse: 23.5727
# [800]	training's rmse: 3.19895	valid_1's rmse: 23.5686
# [850]	training's rmse: 2.91134	valid_1's rmse: 23.5639
# [900]	training's rmse: 2.66441	valid_1's rmse: 23.5562
# [950]	training's rmse: 2.44454	valid_1's rmse: 23.5494
# [1000]	training's rmse: 2.24861	valid_1's rmse: 23.5496
# [1050]	training's rmse: 2.072	valid_1's rmse: 23.5412
# [1100]	training's rmse: 1.91633	valid_1's rmse: 23.5405
# [1150]	training's rmse: 1.77779	valid_1's rmse: 23.5382
# [1200]	training's rmse: 1.65321	valid_1's rmse: 23.5376
# [1250]	training's rmse: 1.53802	valid_1's rmse: 23.5366
# [1300]	training's rmse: 1.43659	valid_1's rmse: 23.5322
# [1350]	training's rmse: 1.34635	valid_1's rmse: 23.536
# [1400]	training's rmse: 1.26412	valid_1's rmse: 23.5329
# [1450]	training's rmse: 1.18909	valid_1's rmse: 23.5339
# [1500]	training's rmse: 1.12001	valid_1's rmse: 23.5324
# Early stopping, best iteration is:
# [1318]	training's rmse: 1.40326	valid_1's rmse: 23.5296
#
# fold n°1
#
#
# **** target ****
#
# Training until validation scores don't improve for 200 rounds
# [50]	training's rmse: 22.7298	valid_1's rmse: 37.9927
# [100]	training's rmse: 16.9868	valid_1's rmse: 36.8561
# [150]	training's rmse: 13.7186	valid_1's rmse: 36.5304
# [200]	training's rmse: 11.4814	valid_1's rmse: 36.4377
# [250]	training's rmse: 9.8378	valid_1's rmse: 36.3358
# [300]	training's rmse: 8.56487	valid_1's rmse: 36.2562
# [350]	training's rmse: 7.56095	valid_1's rmse: 36.2434
# [400]	training's rmse: 6.69399	valid_1's rmse: 36.1985
# [450]	training's rmse: 5.98222	valid_1's rmse: 36.1621
# [500]	training's rmse: 5.37495	valid_1's rmse: 36.1492
# [550]	training's rmse: 4.84956	valid_1's rmse: 36.1297
# [600]	training's rmse: 4.39609	valid_1's rmse: 36.1161
# [650]	training's rmse: 3.99494	valid_1's rmse: 36.1046
# [700]	training's rmse: 3.64368	valid_1's rmse: 36.0888
# [750]	training's rmse: 3.32997	valid_1's rmse: 36.0801
# [800]	training's rmse: 3.05865	valid_1's rmse: 36.0704
# [850]	training's rmse: 2.81357	valid_1's rmse: 36.0646
# [900]	training's rmse: 2.59068	valid_1's rmse: 36.0685
# [950]	training's rmse: 2.39244	valid_1's rmse: 36.0693
# [1000]	training's rmse: 2.22223	valid_1's rmse: 36.0679
# Early stopping, best iteration is:
# [832]	training's rmse: 2.89914	valid_1's rmse: 36.064
#
# fold n°2
#
#
# **** target ****
#
# Training until validation scores don't improve for 200 rounds
# [50]	training's rmse: 23.4015	valid_1's rmse: 34.4601
# [100]	training's rmse: 17.8241	valid_1's rmse: 32.8715
# [150]	training's rmse: 14.5616	valid_1's rmse: 32.1789
# [200]	training's rmse: 12.2967	valid_1's rmse: 31.7975
# [250]	training's rmse: 10.5369	valid_1's rmse: 31.6261
# [300]	training's rmse: 9.17113	valid_1's rmse: 31.4942
# [350]	training's rmse: 8.00512	valid_1's rmse: 31.3952
# [400]	training's rmse: 7.04102	valid_1's rmse: 31.3142
# [450]	training's rmse: 6.23061	valid_1's rmse: 31.2568
# [500]	training's rmse: 5.53806	valid_1's rmse: 31.2007
# [550]	training's rmse: 4.93425	valid_1's rmse: 31.165
# [600]	training's rmse: 4.39861	valid_1's rmse: 31.1323
# [650]	training's rmse: 3.92327	valid_1's rmse: 31.1087
# [700]	training's rmse: 3.51076	valid_1's rmse: 31.0801
# [750]	training's rmse: 3.15814	valid_1's rmse: 31.0675
# [800]	training's rmse: 2.83884	valid_1's rmse: 31.0549
# [850]	training's rmse: 2.5621	valid_1's rmse: 31.0477
# [900]	training's rmse: 2.3159	valid_1's rmse: 31.0246
# [950]	training's rmse: 2.09796	valid_1's rmse: 31.0158
# [1000]	training's rmse: 1.89948	valid_1's rmse: 31.0077
# [1050]	training's rmse: 1.72069	valid_1's rmse: 30.9991
# [1100]	training's rmse: 1.56475	valid_1's rmse: 30.9923
# [1150]	training's rmse: 1.42022	valid_1's rmse: 30.9893
# [1200]	training's rmse: 1.29096	valid_1's rmse: 30.9863
# [1250]	training's rmse: 1.17052	valid_1's rmse: 30.9838
# [1300]	training's rmse: 1.06583	valid_1's rmse: 30.9817
# [1350]	training's rmse: 0.972699	valid_1's rmse: 30.9803
# [1400]	training's rmse: 0.887039	valid_1's rmse: 30.9774
# [1450]	training's rmse: 0.808674	valid_1's rmse: 30.9747
# [1500]	training's rmse: 0.736973	valid_1's rmse: 30.9732
# [1550]	training's rmse: 0.673231	valid_1's rmse: 30.974
# [1600]	training's rmse: 0.616925	valid_1's rmse: 30.9729
# [1650]	training's rmse: 0.565156	valid_1's rmse: 30.9714
# [1700]	training's rmse: 0.518019	valid_1's rmse: 30.9708
# [1750]	training's rmse: 0.474886	valid_1's rmse: 30.9714
# [1800]	training's rmse: 0.436336	valid_1's rmse: 30.9708
# [1850]	training's rmse: 0.400432	valid_1's rmse: 30.9696
# [1900]	training's rmse: 0.366934	valid_1's rmse: 30.9689
# [1950]	training's rmse: 0.337635	valid_1's rmse: 30.9685
# [2000]	training's rmse: 0.310591	valid_1's rmse: 30.9685
# [2050]	training's rmse: 0.285917	valid_1's rmse: 30.9682
# [2100]	training's rmse: 0.263678	valid_1's rmse: 30.968
# [2150]	training's rmse: 0.243477	valid_1's rmse: 30.9676
# [2200]	training's rmse: 0.224516	valid_1's rmse: 30.967
# Did not meet early stopping. Best iteration is:
# [2200]	training's rmse: 0.224516	valid_1's rmse: 30.967
#
# fold n°3
#
#
# **** target ****
#
# Training until validation scores don't improve for 200 rounds
# [50]	training's rmse: 23.9575	valid_1's rmse: 26.4593
# [100]	training's rmse: 18.3669	valid_1's rmse: 24.5285
# [150]	training's rmse: 15.1227	valid_1's rmse: 23.7108
# [200]	training's rmse: 12.8199	valid_1's rmse: 23.4685
# [250]	training's rmse: 11.0556	valid_1's rmse: 23.2851
# [300]	training's rmse: 9.64004	valid_1's rmse: 23.2551
# [350]	training's rmse: 8.50626	valid_1's rmse: 23.2854
# [400]	training's rmse: 7.55704	valid_1's rmse: 23.2508
# [450]	training's rmse: 6.74495	valid_1's rmse: 23.2238
# [500]	training's rmse: 6.04229	valid_1's rmse: 23.2292
# [550]	training's rmse: 5.42601	valid_1's rmse: 23.2705
# [600]	training's rmse: 4.88602	valid_1's rmse: 23.2689
# Early stopping, best iteration is:
# [439]	training's rmse: 6.91219	valid_1's rmse: 23.1721
#
# fold n°4
#
#
# **** target ****
#
# Training until validation scores don't improve for 200 rounds
# [50]	training's rmse: 23.8554	valid_1's rmse: 31.0746
# [100]	training's rmse: 18.2662	valid_1's rmse: 28.1955
# [150]	training's rmse: 15.0461	valid_1's rmse: 27.0374
# [200]	training's rmse: 12.7195	valid_1's rmse: 26.5126
# [250]	training's rmse: 10.9636	valid_1's rmse: 26.1884
# [300]	training's rmse: 9.58757	valid_1's rmse: 25.985
# [350]	training's rmse: 8.43609	valid_1's rmse: 25.8479
# [400]	training's rmse: 7.4887	valid_1's rmse: 25.7671
# [450]	training's rmse: 6.66858	valid_1's rmse: 25.6958
# [500]	training's rmse: 5.97065	valid_1's rmse: 25.6458
# [550]	training's rmse: 5.34829	valid_1's rmse: 25.5954
# [600]	training's rmse: 4.81757	valid_1's rmse: 25.5473
# [650]	training's rmse: 4.35712	valid_1's rmse: 25.5184
# [700]	training's rmse: 3.95053	valid_1's rmse: 25.4885
# [750]	training's rmse: 3.58483	valid_1's rmse: 25.4748
# [800]	training's rmse: 3.25792	valid_1's rmse: 25.4644
# [850]	training's rmse: 2.97879	valid_1's rmse: 25.4487
# [900]	training's rmse: 2.7258	valid_1's rmse: 25.4403
# [950]	training's rmse: 2.50183	valid_1's rmse: 25.4257
# [1000]	training's rmse: 2.30195	valid_1's rmse: 25.4203
# [1050]	training's rmse: 2.12403	valid_1's rmse: 25.4196
# [1100]	training's rmse: 1.9648	valid_1's rmse: 25.4112
# [1150]	training's rmse: 1.82397	valid_1's rmse: 25.4107
# [1200]	training's rmse: 1.69809	valid_1's rmse: 25.4071
# [1250]	training's rmse: 1.5849	valid_1's rmse: 25.4035
# [1300]	training's rmse: 1.48317	valid_1's rmse: 25.4019
# [1350]	training's rmse: 1.38882	valid_1's rmse: 25.3978
# [1400]	training's rmse: 1.30484	valid_1's rmse: 25.3946
# [1450]	training's rmse: 1.22763	valid_1's rmse: 25.3934
# [1500]	training's rmse: 1.15872	valid_1's rmse: 25.3891
# [1550]	training's rmse: 1.096	valid_1's rmse: 25.3883
# [1600]	training's rmse: 1.03781	valid_1's rmse: 25.387
# [1650]	training's rmse: 0.98551	valid_1's rmse: 25.3878
# [1700]	training's rmse: 0.937564	valid_1's rmse: 25.3849
# [1750]	training's rmse: 0.89241	valid_1's rmse: 25.3821
# [1800]	training's rmse: 0.85121	valid_1's rmse: 25.3815
# [1850]	training's rmse: 0.813184	valid_1's rmse: 25.3812
# [1900]	training's rmse: 0.777981	valid_1's rmse: 25.3813
# [1950]	training's rmse: 0.743645	valid_1's rmse: 25.3814
# [2000]	training's rmse: 0.712584	valid_1's rmse: 25.3812
# [2050]	training's rmse: 0.682526	valid_1's rmse: 25.3804
# [2100]	training's rmse: 0.655212	valid_1's rmse: 25.3808
# [2150]	training's rmse: 0.63005	valid_1's rmse: 25.3809
# [2200]	training's rmse: 0.60604	valid_1's rmse: 25.3807
# Did not meet early stopping. Best iteration is:
# [2200]	training's rmse: 0.60604	valid_1's rmse: 25.3807
#
# fold n°5
#
#
# **** target ****
#
# Training until validation scores don't improve for 200 rounds
# [50]	training's rmse: 23.8574	valid_1's rmse: 28.0388
# [100]	training's rmse: 18.1814	valid_1's rmse: 25.798
# [150]	training's rmse: 14.9582	valid_1's rmse: 25.0969
# [200]	training's rmse: 12.6705	valid_1's rmse: 24.6713
# [250]	training's rmse: 10.9189	valid_1's rmse: 24.4494
# [300]	training's rmse: 9.53734	valid_1's rmse: 24.328
# [350]	training's rmse: 8.36743	valid_1's rmse: 24.2112
# [400]	training's rmse: 7.41912	valid_1's rmse: 24.1313
# [450]	training's rmse: 6.59399	valid_1's rmse: 24.0735
# [500]	training's rmse: 5.88501	valid_1's rmse: 24.0129
# [550]	training's rmse: 5.27485	valid_1's rmse: 23.9749
# [600]	training's rmse: 4.74927	valid_1's rmse: 23.9285
# [650]	training's rmse: 4.29277	valid_1's rmse: 23.9181
# [700]	training's rmse: 3.89436	valid_1's rmse: 23.9008
# [750]	training's rmse: 3.53967	valid_1's rmse: 23.8749
# [800]	training's rmse: 3.22635	valid_1's rmse: 23.8641
# [850]	training's rmse: 2.94871	valid_1's rmse: 23.8482
# [900]	training's rmse: 2.70543	valid_1's rmse: 23.8387
# [950]	training's rmse: 2.48921	valid_1's rmse: 23.8375
# [1000]	training's rmse: 2.2926	valid_1's rmse: 23.8256
# [1050]	training's rmse: 2.11794	valid_1's rmse: 23.8197
# [1100]	training's rmse: 1.95851	valid_1's rmse: 23.818
# [1150]	training's rmse: 1.81801	valid_1's rmse: 23.8144
# [1200]	training's rmse: 1.6893	valid_1's rmse: 23.8142
# [1250]	training's rmse: 1.57516	valid_1's rmse: 23.8108
# [1300]	training's rmse: 1.47225	valid_1's rmse: 23.8132
# [1350]	training's rmse: 1.37851	valid_1's rmse: 23.8117
# [1400]	training's rmse: 1.29714	valid_1's rmse: 23.8116
# [1450]	training's rmse: 1.22166	valid_1's rmse: 23.8076
# [1500]	training's rmse: 1.15254	valid_1's rmse: 23.807
# [1550]	training's rmse: 1.08974	valid_1's rmse: 23.8082
# [1600]	training's rmse: 1.03241	valid_1's rmse: 23.8077
# [1650]	training's rmse: 0.977918	valid_1's rmse: 23.8056
# [1700]	training's rmse: 0.929233	valid_1's rmse: 23.8051
# [1750]	training's rmse: 0.883851	valid_1's rmse: 23.8045
# [1800]	training's rmse: 0.841728	valid_1's rmse: 23.8053
# [1850]	training's rmse: 0.803497	valid_1's rmse: 23.8043
# [1900]	training's rmse: 0.767369	valid_1's rmse: 23.8044
# [1950]	training's rmse: 0.733475	valid_1's rmse: 23.804
# [2000]	training's rmse: 0.700317	valid_1's rmse: 23.8042
# [2050]	training's rmse: 0.670374	valid_1's rmse: 23.8032
# [2100]	training's rmse: 0.642685	valid_1's rmse: 23.8043
# [2150]	training's rmse: 0.617088	valid_1's rmse: 23.8047
# [2200]	training's rmse: 0.591677	valid_1's rmse: 23.8045
# Did not meet early stopping. Best iteration is:
# [2200]	training's rmse: 0.591677	valid_1's rmse: 23.8045
#
# fold n°6
#
#
# **** target ****
#
# Training until validation scores don't improve for 200 rounds
# [50]	training's rmse: 23.5264	valid_1's rmse: 34.1108
# [100]	training's rmse: 17.9282	valid_1's rmse: 33.3752
# [150]	training's rmse: 14.7296	valid_1's rmse: 32.9878
# [200]	training's rmse: 12.4561	valid_1's rmse: 32.6144
# [250]	training's rmse: 10.7421	valid_1's rmse: 32.3965
# [300]	training's rmse: 9.38234	valid_1's rmse: 32.2974
# [350]	training's rmse: 8.26667	valid_1's rmse: 32.2099
# [400]	training's rmse: 7.3102	valid_1's rmse: 32.1498
# [450]	training's rmse: 6.51287	valid_1's rmse: 32.11
# [500]	training's rmse: 5.82861	valid_1's rmse: 32.0615
# [550]	training's rmse: 5.22423	valid_1's rmse: 32.0356
# [600]	training's rmse: 4.70081	valid_1's rmse: 32.0129
# [650]	training's rmse: 4.24463	valid_1's rmse: 31.9829
# [700]	training's rmse: 3.84907	valid_1's rmse: 31.9651
# [750]	training's rmse: 3.49173	valid_1's rmse: 31.9416
# [800]	training's rmse: 3.18459	valid_1's rmse: 31.9295
# [850]	training's rmse: 2.91274	valid_1's rmse: 31.9105
# [900]	training's rmse: 2.67138	valid_1's rmse: 31.905
# [950]	training's rmse: 2.45902	valid_1's rmse: 31.9019
# [1000]	training's rmse: 2.26348	valid_1's rmse: 31.8953
# [1050]	training's rmse: 2.09205	valid_1's rmse: 31.8917
# [1100]	training's rmse: 1.93731	valid_1's rmse: 31.8834
# [1150]	training's rmse: 1.79717	valid_1's rmse: 31.8799
# [1200]	training's rmse: 1.67481	valid_1's rmse: 31.8788
# [1250]	training's rmse: 1.56378	valid_1's rmse: 31.8733
# [1300]	training's rmse: 1.46273	valid_1's rmse: 31.8685
# [1350]	training's rmse: 1.37043	valid_1's rmse: 31.8651
# [1400]	training's rmse: 1.28638	valid_1's rmse: 31.8617
# [1450]	training's rmse: 1.21175	valid_1's rmse: 31.8581
# [1500]	training's rmse: 1.14255	valid_1's rmse: 31.8557
# [1550]	training's rmse: 1.07774	valid_1's rmse: 31.8545
# [1600]	training's rmse: 1.02099	valid_1's rmse: 31.8509
# [1650]	training's rmse: 0.967048	valid_1's rmse: 31.8501
# [1700]	training's rmse: 0.918682	valid_1's rmse: 31.8488
# [1750]	training's rmse: 0.873926	valid_1's rmse: 31.848
# [1800]	training's rmse: 0.83355	valid_1's rmse: 31.8471
# [1850]	training's rmse: 0.795388	valid_1's rmse: 31.8457
# [1900]	training's rmse: 0.759355	valid_1's rmse: 31.8453
# [1950]	training's rmse: 0.725416	valid_1's rmse: 31.8448
# [2000]	training's rmse: 0.694279	valid_1's rmse: 31.8445
# [2050]	training's rmse: 0.665183	valid_1's rmse: 31.8431
# [2100]	training's rmse: 0.637214	valid_1's rmse: 31.8421
# [2150]	training's rmse: 0.612044	valid_1's rmse: 31.8421
# [2200]	training's rmse: 0.587675	valid_1's rmse: 31.8419
# Did not meet early stopping. Best iteration is:
# [2200]	training's rmse: 0.587675	valid_1's rmse: 31.8419
#
# fold n°7
#
#
# **** target ****
#
# Training until validation scores don't improve for 200 rounds
# [50]	training's rmse: 24.0416	valid_1's rmse: 28.2076
# [100]	training's rmse: 18.3939	valid_1's rmse: 25.6519
# [150]	training's rmse: 15.0981	valid_1's rmse: 24.607
# [200]	training's rmse: 12.7141	valid_1's rmse: 24.0291
# [250]	training's rmse: 10.9755	valid_1's rmse: 23.7379
# [300]	training's rmse: 9.57905	valid_1's rmse: 23.5582
# [350]	training's rmse: 8.43777	valid_1's rmse: 23.4567
# [400]	training's rmse: 7.45775	valid_1's rmse: 23.3765
# [450]	training's rmse: 6.64905	valid_1's rmse: 23.3195
# [500]	training's rmse: 5.94705	valid_1's rmse: 23.2879
# [550]	training's rmse: 5.33441	valid_1's rmse: 23.2446
# [600]	training's rmse: 4.8102	valid_1's rmse: 23.1913
# [650]	training's rmse: 4.34329	valid_1's rmse: 23.1792
# [700]	training's rmse: 3.9433	valid_1's rmse: 23.1531
# [750]	training's rmse: 3.58383	valid_1's rmse: 23.1373
# [800]	training's rmse: 3.26387	valid_1's rmse: 23.1196
# [850]	training's rmse: 2.98068	valid_1's rmse: 23.1106
# [900]	training's rmse: 2.73234	valid_1's rmse: 23.1072
# [950]	training's rmse: 2.5103	valid_1's rmse: 23.0968
# [1000]	training's rmse: 2.31517	valid_1's rmse: 23.0944
# [1050]	training's rmse: 2.14134	valid_1's rmse: 23.0902
# [1100]	training's rmse: 1.98521	valid_1's rmse: 23.0811
# [1150]	training's rmse: 1.84394	valid_1's rmse: 23.0764
# [1200]	training's rmse: 1.7134	valid_1's rmse: 23.0743
# [1250]	training's rmse: 1.60225	valid_1's rmse: 23.0698
# [1300]	training's rmse: 1.49681	valid_1's rmse: 23.0659
# [1350]	training's rmse: 1.40086	valid_1's rmse: 23.0624
# [1400]	training's rmse: 1.31567	valid_1's rmse: 23.0598
# [1450]	training's rmse: 1.23823	valid_1's rmse: 23.0595
# [1500]	training's rmse: 1.16766	valid_1's rmse: 23.0558
# [1550]	training's rmse: 1.10255	valid_1's rmse: 23.0547
# [1600]	training's rmse: 1.04369	valid_1's rmse: 23.0538
# [1650]	training's rmse: 0.989666	valid_1's rmse: 23.0522
# [1700]	training's rmse: 0.94046	valid_1's rmse: 23.0512
# [1750]	training's rmse: 0.893804	valid_1's rmse: 23.0515
# [1800]	training's rmse: 0.851672	valid_1's rmse: 23.0519
# [1850]	training's rmse: 0.811792	valid_1's rmse: 23.0516
# [1900]	training's rmse: 0.775827	valid_1's rmse: 23.0506
# [1950]	training's rmse: 0.742244	valid_1's rmse: 23.0503
# [2000]	training's rmse: 0.709426	valid_1's rmse: 23.0499
# [2050]	training's rmse: 0.679692	valid_1's rmse: 23.0497
# [2100]	training's rmse: 0.651647	valid_1's rmse: 23.0503
# [2150]	training's rmse: 0.625777	valid_1's rmse: 23.0492
# [2200]	training's rmse: 0.601317	valid_1's rmse: 23.0491
# Did not meet early stopping. Best iteration is:
# [2200]	training's rmse: 0.601317	valid_1's rmse: 23.0491
#
# fold n°8
#
#
# **** target ****
#
# Training until validation scores don't improve for 200 rounds
# [50]	training's rmse: 23.8293	valid_1's rmse: 30.4038
# [100]	training's rmse: 18.2359	valid_1's rmse: 27.9328
# [150]	training's rmse: 15.0141	valid_1's rmse: 26.989
# [200]	training's rmse: 12.6608	valid_1's rmse: 26.492
# [250]	training's rmse: 10.9009	valid_1's rmse: 26.2159
# [300]	training's rmse: 9.50451	valid_1's rmse: 26.0608
# [350]	training's rmse: 8.36674	valid_1's rmse: 25.965
# [400]	training's rmse: 7.39597	valid_1's rmse: 25.8903
# [450]	training's rmse: 6.59166	valid_1's rmse: 25.8243
# [500]	training's rmse: 5.89108	valid_1's rmse: 25.7827
# [550]	training's rmse: 5.27677	valid_1's rmse: 25.7653
# [600]	training's rmse: 4.75239	valid_1's rmse: 25.7619
# [650]	training's rmse: 4.27951	valid_1's rmse: 25.7378
# [700]	training's rmse: 3.86874	valid_1's rmse: 25.7232
# [750]	training's rmse: 3.51438	valid_1's rmse: 25.6926
# [800]	training's rmse: 3.19936	valid_1's rmse: 25.6861
# [850]	training's rmse: 2.91973	valid_1's rmse: 25.6786
# [900]	training's rmse: 2.67167	valid_1's rmse: 25.6723
# [950]	training's rmse: 2.44933	valid_1's rmse: 25.6573
# [1000]	training's rmse: 2.25287	valid_1's rmse: 25.6511
# [1050]	training's rmse: 2.0794	valid_1's rmse: 25.6455
# [1100]	training's rmse: 1.92649	valid_1's rmse: 25.6383
# [1150]	training's rmse: 1.78902	valid_1's rmse: 25.6311
# [1200]	training's rmse: 1.66609	valid_1's rmse: 25.6289
# [1250]	training's rmse: 1.55434	valid_1's rmse: 25.6248
# [1300]	training's rmse: 1.45357	valid_1's rmse: 25.6225
# [1350]	training's rmse: 1.36517	valid_1's rmse: 25.6221
# [1400]	training's rmse: 1.28282	valid_1's rmse: 25.6192
# [1450]	training's rmse: 1.2099	valid_1's rmse: 25.6181
# [1500]	training's rmse: 1.14281	valid_1's rmse: 25.6165
# [1550]	training's rmse: 1.0812	valid_1's rmse: 25.6146
# [1600]	training's rmse: 1.02589	valid_1's rmse: 25.6141
# [1650]	training's rmse: 0.975083	valid_1's rmse: 25.6121
# [1700]	training's rmse: 0.92853	valid_1's rmse: 25.6106
# [1750]	training's rmse: 0.885294	valid_1's rmse: 25.6103
# [1800]	training's rmse: 0.844418	valid_1's rmse: 25.6103
# [1850]	training's rmse: 0.806237	valid_1's rmse: 25.6104
# [1900]	training's rmse: 0.771338	valid_1's rmse: 25.6098
# [1950]	training's rmse: 0.738845	valid_1's rmse: 25.6093
# [2000]	training's rmse: 0.708226	valid_1's rmse: 25.6091
# [2050]	training's rmse: 0.679555	valid_1's rmse: 25.6089
# [2100]	training's rmse: 0.652802	valid_1's rmse: 25.6086
# [2150]	training's rmse: 0.628233	valid_1's rmse: 25.6073
# [2200]	training's rmse: 0.604732	valid_1's rmse: 25.6073
# Did not meet early stopping. Best iteration is:
# [2200]	training's rmse: 0.604732	valid_1's rmse: 25.6073
#
# fold n°9
#
#
# **** target ****
#
# Training until validation scores don't improve for 200 rounds
# [50]	training's rmse: 23.6896	valid_1's rmse: 32.419
# [100]	training's rmse: 18.0802	valid_1's rmse: 29.9712
# [150]	training's rmse: 14.8196	valid_1's rmse: 29.1629
# [200]	training's rmse: 12.554	valid_1's rmse: 28.783
# [250]	training's rmse: 10.8023	valid_1's rmse: 28.6019
# [300]	training's rmse: 9.43124	valid_1's rmse: 28.4805
# [350]	training's rmse: 8.28986	valid_1's rmse: 28.3851
# [400]	training's rmse: 7.34086	valid_1's rmse: 28.3244
# [450]	training's rmse: 6.54902	valid_1's rmse: 28.2752
# [500]	training's rmse: 5.85489	valid_1's rmse: 28.2484
# [550]	training's rmse: 5.2721	valid_1's rmse: 28.2126
# [600]	training's rmse: 4.75472	valid_1's rmse: 28.1788
# [650]	training's rmse: 4.30237	valid_1's rmse: 28.1577
# [700]	training's rmse: 3.8978	valid_1's rmse: 28.1454
# [750]	training's rmse: 3.54262	valid_1's rmse: 28.1381
# [800]	training's rmse: 3.23763	valid_1's rmse: 28.1279
# [850]	training's rmse: 2.96144	valid_1's rmse: 28.1209
# [900]	training's rmse: 2.71843	valid_1's rmse: 28.1161
# [950]	training's rmse: 2.50277	valid_1's rmse: 28.1071
# [1000]	training's rmse: 2.30954	valid_1's rmse: 28.1039
# [1050]	training's rmse: 2.14152	valid_1's rmse: 28.0998
# [1100]	training's rmse: 1.98886	valid_1's rmse: 28.0944
# [1150]	training's rmse: 1.85337	valid_1's rmse: 28.0918
# [1200]	training's rmse: 1.72981	valid_1's rmse: 28.089
# [1250]	training's rmse: 1.62072	valid_1's rmse: 28.0892
# [1300]	training's rmse: 1.52149	valid_1's rmse: 28.0864
# [1350]	training's rmse: 1.43416	valid_1's rmse: 28.083
# [1400]	training's rmse: 1.35362	valid_1's rmse: 28.0802
# [1450]	training's rmse: 1.28075	valid_1's rmse: 28.0807
# [1500]	training's rmse: 1.21448	valid_1's rmse: 28.0805
# [1550]	training's rmse: 1.15203	valid_1's rmse: 28.0802
# [1600]	training's rmse: 1.09453	valid_1's rmse: 28.08
# [1650]	training's rmse: 1.04208	valid_1's rmse: 28.0795
# [1700]	training's rmse: 0.994771	valid_1's rmse: 28.0779
# [1750]	training's rmse: 0.950426	valid_1's rmse: 28.0772
# [1800]	training's rmse: 0.908837	valid_1's rmse: 28.0777
# [1850]	training's rmse: 0.870244	valid_1's rmse: 28.0789
# [1900]	training's rmse: 0.833486	valid_1's rmse: 28.0777
# [1950]	training's rmse: 0.799802	valid_1's rmse: 28.0781
# Early stopping, best iteration is:
# [1781]	training's rmse: 0.924444	valid_1's rmse: 28.0767

# %%
_ = plt.figure(figsize=(10, 10))
fi = pd.Series(index=features, data=clf.feature_importance())
_ = fi.sort_values()[-20:].plot(kind='barh')

# %%
rmse(target.values, oofs_df['target'].values)
# Out:
# 27.477780318550085

# %%
predictions_test = preds_df['target'] 
predictions_test[predictions_test < 0] = 0

# %%
SUB_FILE_NAME = 'preds_lgbm_v3.csv'
sub_df = pd.DataFrame()
sub_df[ID_COL] = test[ID_COL]
sub_df[TARGET_COL] = predictions_test
sub_df.to_csv(SUB_FILE_NAME, index=False)
sub_df.head(10)
# Out:
#         Place_ID X Date     target
# 0  0OS9LVX X 2020-01-02  31.378380
# 1  0OS9LVX X 2020-01-03  29.683030
# 2  0OS9LVX X 2020-01-04  26.890229
# 3  0OS9LVX X 2020-01-05  31.475699
# 4  0OS9LVX X 2020-01-06  49.269760
# 5  0OS9LVX X 2020-01-07  58.820854
# 6  0OS9LVX X 2020-01-08  28.139429
# 7  0OS9LVX X 2020-01-09  27.558602
# 8  0OS9LVX X 2020-01-10  30.558964
# 9  0OS9LVX X 2020-01-11  43.673940

# %%
sub_df[TARGET_COL].describe()
# Out:
# count    16136.000000
# mean        57.844240
# std         35.230891
# min          3.227130
# 25%         31.392769
# 50%         48.269874
# 75%         75.199107
# max        273.497813
# Name: target, dtype: float64
